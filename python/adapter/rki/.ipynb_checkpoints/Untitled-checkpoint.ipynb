# %%
import requests
import pandas as pd
from pprint import pprint
import json
import re
from datetime import datetime

# %%
r = requests.get("https://services7.arcgis.com/mOBPykOjAyBO2ZKk/arcgis/rest/services/RKI_COVID19/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
j = r.json()["features"]
df = pd.DataFrame()
ages_re = re.compile('\d+')
for d in j:
    outData = {}
    data = d['attributes']
    adm = []
    adm.append("DE")
    if data['IdBundesland'] < 10:
        adm.append('0'  + str(data['IdBundesland']))
    else: 
        adm.append(str(data['IdBundesland']))
    lk = int(data['IdBundesland']) % 100
    if lk < 10: 
        lk = '00' + str(lk)
    elif lk < 100: 
        lk = '0' + str(lk)
    adm.append(lk)
    outData['adm'] = adm
    outData['sex'] = data['Geschlecht']
    
    matches = re.findall(ages_re,data['Altersgruppe'])
    agerange = {}
    if len(matches) == 2: 
        agerange['lower'] = int(matches[0])
        agerange['upper'] = int(matches[1])
    else: 
        agerange['lower'] = 0
        agerange['upper'] = 0  
                                
    outData['ageRange'] = agerange
    outData['infected'] = data['AnzahlFall']
    outData['dead'] = data['AnzahlTodesfall']
    dt = datetime.fromtimestamp(data['Meldedatum'] / 1000)
    outData['date'] = f"{dt:%Y-%m-%d}"
    outData['source'] = "RKI"
    outData['tested'] = 0
    outData['recovered'] = 0
    pprint(outData)
# Out:
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-08',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-02-29',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 1,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-05',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-02',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 0, 'upper': 4},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 0, 'upper': 4},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 5, 'upper': 14},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-09',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-03',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 4,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 4,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 5,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 4,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 4,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 4,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-06',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-09',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 5, 'upper': 14},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 5, 'upper': 14},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 5, 'upper': 14},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 4,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-02-28',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-06',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-21',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 5, 'upper': 14},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-19',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '01', '001'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '02', '002'],
#  'ageRange': {'lower': 0, 'upper': 4},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '02', '002'],
#  'ageRange': {'lower': 0, 'upper': 4},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '02', '002'],
#  'ageRange': {'lower': 0, 'upper': 4},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '02', '002'],
#  'ageRange': {'lower': 0, 'upper': 4},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '02', '002'],
#  'ageRange': {'lower': 0, 'upper': 4},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '02', '002'],
#  'ageRange': {'lower': 0, 'upper': 4},
# ...
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'unbekannt',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'unbekannt',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 5, 'upper': 14},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 5, 'upper': 14},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-03',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-05',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 4,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 9,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 5,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 4,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 5,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-05',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 4},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 5, 'upper': 14},
#  'date': '2020-03-09',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-09',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-03',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-09',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 4,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 5,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 8,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-03',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-09',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-02',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 3,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-04',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 7,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-16',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 9,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 5,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-20',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-09',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-11',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-10',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-05',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-17',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-05',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 35, 'upper': 59},
#  'date': '2020-03-14',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 60, 'upper': 79},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 0},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 4},
#  'date': '2020-03-05',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 0, 'upper': 4},
#  'date': '2020-03-18',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'W',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-12',
#  'dead': 0,
#  'infected': 4,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-13',
#  'dead': 0,
#  'infected': 2,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}
# {'adm': ['DE', '05', '005'],
#  'ageRange': {'lower': 15, 'upper': 34},
#  'date': '2020-03-15',
#  'dead': 0,
#  'infected': 1,
#  'recovered': 0,
#  'sex': 'M',
#  'source': 'RKI',
#  'tested': 0}

# %%
df = pd.read_json(j)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
